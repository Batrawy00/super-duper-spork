# %%
from IPython.display import clear_output
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")

# !git clone https://github.com/facefusion/facefusion.git
# %cd ./facefusion
# !python install.py --onnxruntime cuda-11.8 --skip-conda

clear_output()
print("Installed!")
print(device)

# %%
import os

# Path to the default.py file
file_path = '/workspaces/codespaces-jupyter/notebooks/facefusion/facefusion/uis/layouts/default.py'

if os.path.exists(file_path):
    # Read the content of the file
    with open(file_path, 'r') as file:
        content = file.read()

    # Replace the line with the updated version
    updated_content = content.replace(
        "ui.queue(concurrency_count = concurrency_count).launch(show_api = False, quiet = True, inbrowser = facefusion.globals.open_browser)",
        "ui.queue(concurrency_count = concurrency_count).launch(show_api = False, share=False, quiet = True, inbrowser = facefusion.globals.open_browser)"
    )

    # Write the updated content back to the file
    with open(file_path, 'w') as file:
        file.write(updated_content)
    print(f"Updated {file_path}")
else:
    print(f"File {file_path} not found.")

# %%
# Path to the content_analyser.py file
file_path = '/workspaces/codespaces-jupyter/notebooks/facefusion/facefusion/content_analyser.py'

if os.path.exists(file_path):
    # Read the content of the file
    with open(file_path, 'r') as file:
        content = file.read()

    # Replace the line with the updated version
    updated_content = content.replace("probability > PROBABILITY_LIMIT", "False")

    # Write the updated content back to the file
    with open(file_path, 'w') as file:
        file.write(updated_content)
    print(f"Updated {file_path}")
else:
    print(f"File {file_path} not found.")

# %%
# !curl ipv4.icanhazip.com

# %%
from multiprocessing import Process
import sys
import time

# !touch log.txt
open('log.txt', 'w').close()

def run_app():
    cmd = "python /workspaces/codespaces-jupyter/notebooks/facefusion/run.py & ssh -o StrictHostKeyChecking=no -p 80 -R0:localhost:7860 a.pinggy.io > log.txt"
    os.system(cmd)
    
def print_url():
    print("waiting for output")
    time.sleep(2)
    sys.stdout.flush()
    
    found = False
    with open('log.txt', 'r') as file:
        end_word = '.pinggy.link'
        for line in file:
            start_index = line.find("http:")
            if start_index != -1:
                end_index = line.find(end_word, start_index)
                if end_index != -1:
                    print("😁 😁 😁")
                    print("URL: " + line[start_index:end_index + len(end_word)])
                    print("😁 😁 😁")
                    found = True
    if not found:
        print_url()
    else:
        with open('log.txt', 'r') as file:
            for line in file:
                print(line)
    
p_app = Process(target=run_app)
p_url = Process(target=print_url)
p_app.start()
p_url.start()
p_app.join()
p_url.join()

# %%
# !npm install -g localtunnel

# -------------------------------- #

import os
from subprocess import Popen

tunnel_process = Popen(['lt', '--port', '7860'])
print('Tunnel URL: http://localhost:7860')

# !python /workspaces/codespaces-jupyter/notebooks/facefusion/run.py
